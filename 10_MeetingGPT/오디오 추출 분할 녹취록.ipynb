# %% [markdown]
# # Audio Extraction

# %%
import os
from dotenv import load_dotenv
load_dotenv()
print(f'\tOPENAI_API_KEY={os.getenv("OPENAI_API_KEY")[:20]}')
# Out:
# 	OPENAI_API_KEY=sk-proj-iKU13YeoxNgF

# %% [markdown]
# ## CLI 명령으로 오디오 추출할 경우

# %%
# >ffmpeg -i D:\LANG2509\dataset\mp4\podcast.mp4 -vn D:\LANG2509\dataset\mp4\audio.mp3 -y

# -i 옵션 : input. 입력 파일 지정 (여러개 지정 가능)
# -vn 옵션 : disable video. 비디오는 무시하고 오디오만 추출
# -y 옵션 : 덮어쓰기 할때 y/n 사용자 입력 대디하지 않고 yes 로 진행

# %%
# !ffmpeg -i D:\LANG2509\dataset\mp4\podcast.mp4 -vn D:\LANG2509\dataset\mp4\audio.mp3 -y
# Out:
# ffmpeg version 2025-07-28-git-dc8e753f32-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.1.0 (Rev6, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      60.  6.100 / 60.  6.100
#   libavcodec     62.  8.100 / 62.  8.100
#   libavformat    62.  1.103 / 62.  1.103
#   libavdevice    62.  0.100 / 62.  0.100
#   libavfilter    11.  3.100 / 11.  3.100
#   libswscale      9.  0.100 /  9.  0.100
#   libswresample   6.  0.100 /  6.  0.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\LANG2509\dataset\mp4\podcast.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2025-02-17T14:10:01.000000Z
#     encoder         : Google
#   Duration: 01:13:42.43, start: 0.000000, bitrate: 268 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 136 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2025-02-17T14:10:01.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2025.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2025-02-17T14:10:01.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2025.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'D:\LANG2509\dataset\mp4\audio.mp3':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     TSSE            : Lavf62.1.103
#   Stream #0:0(eng): Audio: mp3, 44100 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.8.100 libmp3lame
#       creation_time   : 2025-02-17T14:10:01.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/17/2025.
#       vendor_id       : [0][0][0][0]
# size=     512KiB time=00:00:44.14 bitrate=  95.0kbits/s speed=87.5x elapsed=0:00:00.50
# size=    1536KiB time=00:01:52.61 bitrate= 111.7kbits/s speed= 110x elapsed=0:00:01.02
# size=    2560KiB time=00:02:59.98 bitrate= 116.5kbits/s speed= 117x elapsed=0:00:01.54
# size=    3840KiB time=00:04:07.66 bitrate= 127.0kbits/s speed= 120x elapsed=0:00:02.05
# size=    4864KiB time=00:05:15.16 bitrate= 126.4kbits/s speed= 123x elapsed=0:00:02.57
# size=    5888KiB time=00:06:23.19 bitrate= 125.9kbits/s speed= 124x elapsed=0:00:03.08
# size=    6912KiB time=00:07:30.06 bitrate= 125.8kbits/s speed= 125x elapsed=0:00:03.59
# size=    7936KiB time=00:08:38.66 bitrate= 125.3kbits/s speed= 126x elapsed=0:00:04.12
# size=    8960KiB time=00:09:44.72 bitrate= 125.5kbits/s speed= 126x elapsed=0:00:04.63
# size=    9984KiB time=00:10:53.16 bitrate= 125.2kbits/s speed= 127x elapsed=0:00:05.15
# size=   11008KiB time=00:11:59.46 bitrate= 125.3kbits/s speed= 127x elapsed=0:00:05.66
# size=   12032KiB time=00:13:05.99 bitrate= 125.4kbits/s speed= 127x elapsed=0:00:06.17
# size=   13312KiB time=00:14:14.57 bitrate= 127.6kbits/s speed= 127x elapsed=0:00:06.70
# size=   14336KiB time=00:15:22.59 bitrate= 127.3kbits/s speed= 128x elapsed=0:00:07.21
# size=   15360KiB time=00:16:28.84 bitrate= 127.2kbits/s speed= 128x elapsed=0:00:07.72
# size=   16384KiB time=00:17:36.70 bitrate= 127.0kbits/s speed= 128x elapsed=0:00:08.24
# size=   17408KiB time=00:18:40.31 bitrate= 127.3kbits/s speed= 128x elapsed=0:00:08.75
# size=   18432KiB time=00:19:49.74 bitrate= 126.9kbits/s speed= 128x elapsed=0:00:09.28
# size=   19456KiB time=00:20:53.77 bitrate= 127.1kbits/s speed= 128x elapsed=0:00:09.79
# size=   20480KiB time=00:21:51.81 bitrate= 127.9kbits/s speed= 127x elapsed=0:00:10.30
# size=   21248KiB time=00:22:52.91 bitrate= 126.8kbits/s speed= 127x elapsed=0:00:10.82
# size=   22272KiB time=00:24:00.05 bitrate= 126.7kbits/s speed= 127x elapsed=0:00:11.33
# size=   23296KiB time=00:25:07.24 bitrate= 126.6kbits/s speed= 127x elapsed=0:00:11.85
# size=   24576KiB time=00:26:15.34 bitrate= 127.8kbits/s speed= 127x elapsed=0:00:12.36
# size=   25600KiB time=00:27:22.11 bitrate= 127.7kbits/s speed= 127x elapsed=0:00:12.88
# size=   26624KiB time=00:28:30.76 bitrate= 127.5kbits/s speed= 128x elapsed=0:00:13.39
# size=   27648KiB time=00:29:40.40 bitrate= 127.2kbits/s speed= 128x elapsed=0:00:13.92
# size=   28672KiB time=00:30:46.83 bitrate= 127.2kbits/s speed= 128x elapsed=0:00:14.42
# size=   29952KiB time=00:31:58.01 bitrate= 127.9kbits/s speed= 128x elapsed=0:00:14.95
# size=   30976KiB time=00:33:06.24 bitrate= 127.8kbits/s speed= 128x elapsed=0:00:15.46
# size=   32000KiB time=00:34:12.99 bitrate= 127.7kbits/s speed= 128x elapsed=0:00:15.97
# size=   33024KiB time=00:35:21.03 bitrate= 127.5kbits/s speed= 129x elapsed=0:00:16.49
# size=   34048KiB time=00:36:29.68 bitrate= 127.4kbits/s speed= 129x elapsed=0:00:17.00
# size=   35072KiB time=00:37:37.42 bitrate= 127.3kbits/s speed= 129x elapsed=0:00:17.51
# size=   36096KiB time=00:38:46.44 bitrate= 127.1kbits/s speed= 129x elapsed=0:00:18.04
# size=   37376KiB time=00:39:52.97 bitrate= 128.0kbits/s speed= 129x elapsed=0:00:18.55
# size=   38400KiB time=00:41:01.38 bitrate= 127.8kbits/s speed= 129x elapsed=0:00:19.06
# size=   39424KiB time=00:42:08.36 bitrate= 127.7kbits/s speed= 129x elapsed=0:00:19.58
# size=   40448KiB time=00:43:16.57 bitrate= 127.6kbits/s speed= 129x elapsed=0:00:20.09
# size=   41472KiB time=00:44:24.04 bitrate= 127.5kbits/s speed= 129x elapsed=0:00:20.61
# size=   42496KiB time=00:45:33.92 bitrate= 127.3kbits/s speed= 129x elapsed=0:00:21.13
# size=   43520KiB time=00:46:41.13 bitrate= 127.3kbits/s speed= 129x elapsed=0:00:21.65
# size=   44800KiB time=00:47:49.00 bitrate= 127.9kbits/s speed= 129x elapsed=0:00:22.17
# size=   45824KiB time=00:48:56.42 bitrate= 127.8kbits/s speed= 129x elapsed=0:00:22.68
# size=   46848KiB time=00:50:04.50 bitrate= 127.7kbits/s speed= 129x elapsed=0:00:23.20
# size=   47872KiB time=00:51:10.09 bitrate= 127.7kbits/s speed= 129x elapsed=0:00:23.72
# size=   48896KiB time=00:52:18.16 bitrate= 127.6kbits/s speed= 129x elapsed=0:00:24.23
# size=   49920KiB time=00:53:26.84 bitrate= 127.5kbits/s speed= 129x elapsed=0:00:24.76
# size=   50944KiB time=00:54:36.25 bitrate= 127.4kbits/s speed= 130x elapsed=0:00:25.28
# size=   52224KiB time=00:55:43.80 bitrate= 127.9kbits/s speed= 130x elapsed=0:00:25.79
# size=   53248KiB time=00:56:53.86 bitrate= 127.8kbits/s speed= 130x elapsed=0:00:26.32
# size=   54272KiB time=00:57:59.61 bitrate= 127.8kbits/s speed= 130x elapsed=0:00:26.83
# size=   55296KiB time=00:59:08.13 bitrate= 127.7kbits/s speed= 130x elapsed=0:00:27.35
# size=   56320KiB time=01:00:15.42 bitrate= 127.6kbits/s speed= 130x elapsed=0:00:27.86
# size=   57344KiB time=01:01:18.79 bitrate= 127.7kbits/s speed= 130x elapsed=0:00:28.38
# size=   58368KiB time=01:02:25.41 bitrate= 127.7kbits/s speed= 130x elapsed=0:00:28.89
# size=   59392KiB time=01:03:34.08 bitrate= 127.6kbits/s speed= 130x elapsed=0:00:29.41
# size=   60416KiB time=01:04:41.58 bitrate= 127.5kbits/s speed= 130x elapsed=0:00:29.92
# size=   61696KiB time=01:05:49.11 bitrate= 128.0kbits/s speed= 130x elapsed=0:00:30.43
# size=   62720KiB time=01:06:59.46 bitrate= 127.8kbits/s speed= 130x elapsed=0:00:30.96
# size=   63744KiB time=01:08:08.00 bitrate= 127.7kbits/s speed= 130x elapsed=0:00:31.48
# size=   64768KiB time=01:09:13.47 bitrate= 127.7kbits/s speed= 130x elapsed=0:00:31.99
# size=   65792KiB time=01:10:22.38 bitrate= 127.6kbits/s speed= 130x elapsed=0:00:32.50
# size=   66816KiB time=01:11:28.15 bitrate= 127.6kbits/s speed= 130x elapsed=0:00:33.02
# size=   67840KiB time=01:12:34.71 bitrate= 127.6kbits/s speed= 130x elapsed=0:00:33.53
# size=   68864KiB time=01:13:30.48 bitrate= 127.9kbits/s speed= 130x elapsed=0:00:34.04
# [out#0/mp3 @ 000001a923c46c40] video:0KiB audio:69101KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000488%
# size=   69101KiB time=01:13:42.42 bitrate= 128.0kbits/s speed= 129x elapsed=0:00:34.20

# %% [markdown]
# ## 오디오 추출 함수 작성

# %%
import subprocess

# %%
base_path = r'D:\LANG2509\dataset\mp4' # 동영상 경로
out_path = r'D:\LANG2509\dataset\mp4\out'# 분할 오디오 추출 경로

import os
if not os.path.exists(out_path):
    os.makedirs(out_path)

# %%
video_file = 'podcast.mp4'
audio_file = 'audio.mp3'

src_path = os.path.join(base_path, video_file)
dst_path = os.path.join(base_path, audio_file)

print(src_path)
print(dst_path)
# Out:
# D:\LANG2509\dataset\mp4\podcast.mp4
# D:\LANG2509\dataset\mp4\audio.mp3

# %%
def extract_audio_from_video(video_path, audio_path):
    # CLI 에서 실행할 command 준비
    # 커맨드창 (CLI) 에서 명령은 아래와 같다.
    #  > ffmpeg -i D:\dataset\podcast.mp4 -vn D:\NLP2501\dataset\audio.mp3 -y
    command = ["ffmpeg", "-i", video_path, "-vn", audio_path, "-y"]
    subprocess.run(command)

# %%
extract_audio_from_video(src_path, dst_path)

# %% [markdown]
# # Cutting the Audio

# %%
# pydub 패키지
#  공식: https://github.com/jiaaro/pydub 
#  pip install pydub  <- 설치 필요  (사전에 ffmpeg 가 설치되고 경로 설정도 되어 있어야 한다)

# %%
from pydub import AudioSegment

# %%
track = AudioSegment.from_mp3(dst_path)

# %%
# track

# %%
track.duration_seconds
# Out:
# 4422.426122448979

# %%
len(track)  # ms
# Out:
# 4422426

# %%
# 오디오의 첫 5분을 선택
five_minutes = 5 * 60 * 1000  # 단위 ms   

first_five = track[:five_minutes]

# %%
# first_five

# %%
first_five.duration_seconds
# Out:
# 300.0

# %%
# export 하기
first_five.export(os.path.join(out_path, 'first_five.mp3'), format='mp3')
# Out:
# <_io.BufferedRandom name='D:\\LANG2509\\dataset\\mp4\\out\\first_five.mp3'>

# %% [markdown]
# ## 오디오 파일 분할

# %%
ten_minutes = 10 * 60 * 1000

# %%
len(track) / ten_minutes
# Out:
# 7.37071

# %%
import math
chunks = math.ceil(len(track) / ten_minutes)

chunks  # 분할될 오디오 덩어리들 개수
# Out:
# 8

# %%
for i in range(chunks):
    start_time = i * ten_minutes
    end_time = (i + 1) * ten_minutes
    print(f'{i} start: {start_time} end {end_time}')
# Out:
# 0 start: 0 end 600000
# 1 start: 600000 end 1200000
# 2 start: 1200000 end 1800000
# 3 start: 1800000 end 2400000
# 4 start: 2400000 end 3000000
# 5 start: 3000000 end 3600000
# 6 start: 3600000 end 4200000
# 7 start: 4200000 end 4800000

# %%
for i in range(chunks):
    start_time = i * ten_minutes
    end_time = (i + 1) * ten_minutes

    chunk = track[start_time:end_time]
    chunk.export(os.path.join(out_path, f'chunk_{i}.mp3'), format='mp3')

# %% [markdown]
# # Whisper Transcript

# %%
import openai

# %%
transcript = openai.audio.transcriptions.create(
    model='whisper-1',
    file=open(os.path.join(out_path, 'chunk_0.mp3'), 'rb'),
    language='en',
)

transcript
# Out:
# Transcription(text="If success is this lagging indicator of commitment now, how can you be sure that you are paying your dues? The best-selling author and host. The number one health and wellness podcast. On Purpose with Jay Shetty. Society has gone in the direction of becoming addicted to pleasure. Yes. Or pleasure-seeking. Where, from the Stoic's perspective, why did we even ever go down that road? Like, why did we leave wisdom and self-control? Or did we never have it at all and we've always been trying to balance it? Yeah. I mean, I guess that's the big question is like, why do we take something that we like too far? Yeah. Right. So the Epicureans would say like, look, drinking is great, but if you have a hangover the next day, was it actually so great? And so, you know, if you, if you push the pleasure too far, it becomes not pleasurable, but in the moment that feels very far away, right? Like in the moment you want the thing now, obviously sex is this thing for people, it's like the thing you're attracted to in this moment, you're not thinking about the shame or the regret or the consequences or the pain or the loss. You're not thinking of all those things you're just thinking of right now. So I think a big part of this, this is where the wisdom comes in, the ability to step back and go, what am I going to think about this after I get it? What am I going to think about this later? And realizing that your mind is very good at tricking you. Just as your mind often tells you like, stop, you're too tired. You can't go any further. You actually have a lot less left in the tank. Your mind also tells you, you need this thing. You won't regret it. It's amazing, you know, whatever. And it's, it's really good at putting those blinders on. And so part of, I think any meditative practice, any philosophical practice, any journaling practice is, is being able to argue with yourself a little bit, to step back and have that conversation about, well, is what I think about this true, is the story I'm telling myself about this true, I think nowhere is this more important than for like ambitious people who have told themselves, I will be happy when I accomplish X, right? Like all the things we need to be most disciplined about ambition is one of them, because it tells you this lie that after I become a New York Times bestseller, after I make a million dollars, after I get a gold medal, then I'll be good. The parents will be proud of me. I'll be happy. Then I can relax. And you have to have the perspective, the wisdom to go, was that ever been true ever in my life before? Has that ever been true in history? And then go, oh, okay, no, I can't tell myself that lie. That doesn't mean you don't work really hard to do stuff, but you're not doing it under the false pretenses that it's going to be conditional to your happiness. Yeah. But there's a part of us that, and I, and I love what you're saying, but there's a part of us that always believes that we are the exception, that we will know how to spend money better, that we'll know how to have love in our life better. Like we won't be the one who fumbles off the edge of a cliff. Like we're smarter than all our friends. Even if we don't say that we're wiser than the people who came before us. And that's the, and that's ego is the enemy. But of course, like that, that idea, I think is what misleads us so much. Yes. Yeah. It's, it's like, okay, you're on the medal stand. You've just won the gold medal and you're not feeling happy for yourself. You're thinking, well, I could have done it faster. You're thinking, oh, I got to do it again. Right? Even in that moment, you're not able to think I'm doing it to myself right now, what I will be doing to myself in the future. And that's this sort of insidious thing. And you can understand why from an evolutionary perspective, it drives the species forward. You can also see the immense personal cost that it inflicts on us because it never allows us to be prese ...

# %%
# first_five

# %%
transcript.text
# Out:
# "If success is this lagging indicator of commitment now, how can you be sure that you are paying your dues? The best-selling author and host. The number one health and wellness podcast. On Purpose with Jay Shetty. Society has gone in the direction of becoming addicted to pleasure. Yes. Or pleasure-seeking. Where, from the Stoic's perspective, why did we even ever go down that road? Like, why did we leave wisdom and self-control? Or did we never have it at all and we've always been trying to balance it? Yeah. I mean, I guess that's the big question is like, why do we take something that we like too far? Yeah. Right. So the Epicureans would say like, look, drinking is great, but if you have a hangover the next day, was it actually so great? And so, you know, if you, if you push the pleasure too far, it becomes not pleasurable, but in the moment that feels very far away, right? Like in the moment you want the thing now, obviously sex is this thing for people, it's like the thing you're attracted to in this moment, you're not thinking about the shame or the regret or the consequences or the pain or the loss. You're not thinking of all those things you're just thinking of right now. So I think a big part of this, this is where the wisdom comes in, the ability to step back and go, what am I going to think about this after I get it? What am I going to think about this later? And realizing that your mind is very good at tricking you. Just as your mind often tells you like, stop, you're too tired. You can't go any further. You actually have a lot less left in the tank. Your mind also tells you, you need this thing. You won't regret it. It's amazing, you know, whatever. And it's, it's really good at putting those blinders on. And so part of, I think any meditative practice, any philosophical practice, any journaling practice is, is being able to argue with yourself a little bit, to step back and have that conversation about, well, is what I think about this true, is the story I'm telling myself about this true, I think nowhere is this more important than for like ambitious people who have told themselves, I will be happy when I accomplish X, right? Like all the things we need to be most disciplined about ambition is one of them, because it tells you this lie that after I become a New York Times bestseller, after I make a million dollars, after I get a gold medal, then I'll be good. The parents will be proud of me. I'll be happy. Then I can relax. And you have to have the perspective, the wisdom to go, was that ever been true ever in my life before? Has that ever been true in history? And then go, oh, okay, no, I can't tell myself that lie. That doesn't mean you don't work really hard to do stuff, but you're not doing it under the false pretenses that it's going to be conditional to your happiness. Yeah. But there's a part of us that, and I, and I love what you're saying, but there's a part of us that always believes that we are the exception, that we will know how to spend money better, that we'll know how to have love in our life better. Like we won't be the one who fumbles off the edge of a cliff. Like we're smarter than all our friends. Even if we don't say that we're wiser than the people who came before us. And that's the, and that's ego is the enemy. But of course, like that, that idea, I think is what misleads us so much. Yes. Yeah. It's, it's like, okay, you're on the medal stand. You've just won the gold medal and you're not feeling happy for yourself. You're thinking, well, I could have done it faster. You're thinking, oh, I got to do it again. Right? Even in that moment, you're not able to think I'm doing it to myself right now, what I will be doing to myself in the future. And that's this sort of insidious thing. And you can understand why from an evolutionary perspective, it drives the species forward. You can also see the immense personal cost that it inflicts on us because it never allows us to be present or content or ha ...

# %% [markdown]
# ## glob 관련 이슈

# %%
from glob import glob

# %%
# glob() 은 파일 이름순서대로 list 를 리턴한다는 보장이 없다.

files = glob(os.path.join(out_path, 'chunk*.mp3'))
files.sort()
files
# Out:
# ['D:\\LANG2509\\dataset\\mp4\\out\\chunk_0.mp3',
#  'D:\\LANG2509\\dataset\\mp4\\out\\chunk_1.mp3',
#  'D:\\LANG2509\\dataset\\mp4\\out\\chunk_2.mp3',
#  'D:\\LANG2509\\dataset\\mp4\\out\\chunk_3.mp3',
#  'D:\\LANG2509\\dataset\\mp4\\out\\chunk_4.mp3',
#  'D:\\LANG2509\\dataset\\mp4\\out\\chunk_5.mp3',
#  'D:\\LANG2509\\dataset\\mp4\\out\\chunk_6.mp3',
#  'D:\\LANG2509\\dataset\\mp4\\out\\chunk_7.mp3']

# %%
def trascribe_chunks(chunk_folder, destination):
    files = glob(os.path.join(chunk_folder, "chunk*.mp3"))
    files.sort()
    for file in files:
        with open(file, "rb") as audio_file, open(destination, "a") as text_file:  # append mode 로 
            print(file, '녹취록 가져오는중...', end='')
            # 각 chunk 별로 녹취록 작성.
            transcript = openai.audio.transcriptions.create(
                model="whisper-1",
                file=audio_file,
                language="en"
            )
            
            text_file.write(transcript.text)  # 곧바로 텍스트 파일에 저장
            print('완료')

# %%
trascribe_chunks(out_path, os.path.join(out_path, 'transcript.txt'))
# Out:
# D:\LANG2509\dataset\mp4\out\chunk_0.mp3 녹취록 가져오는중...완료
# D:\LANG2509\dataset\mp4\out\chunk_1.mp3 녹취록 가져오는중...
