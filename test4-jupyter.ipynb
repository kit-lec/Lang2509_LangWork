# %%
print('hello jupyter')
# Out:
# hello jupyter

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\LANG2509\\LangWork'

# %%
# !where python
# Out:
# D:\LANG2509\LangWork\.venv\Scripts\python.exe
# C:\Users\User\AppData\Local\Programs\Python\Python312\python.exe
# C:\Users\User\AppData\Local\Microsoft\WindowsApps\python.exe
